# %%
import cianparser
import pandas as pd
import time

moscow = cianparser.CianParser(location='Москва')

data = []
for i in range(1, 2):
    a = moscow.get_flats(deal_type='sale', rooms=(1), additional_settings={'start_page': i, 'end_page':i} )
    data.extend(a)
    time.sleep(7)

exel_export = pd.DataFrame(data)
columns = ['author', 'author_type', 'location', 'deal_type', 'accommodation_type', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district', 'street', 'house_number', 'underground', 'residential_complex']
selected_columns = exel_export[columns]
selected_columns.to_csv('cian_parsing.csv', mode='a', header=False, index=False)
# Out:
#                               Preparing to collect information from pages..
# The page from which the collection of information begins:
#  https://cian.ru/cat.php?engine_version=2&p=1&with_neighbors=0&region=1&deal_type=sale&offer_type=flat&room1=1
#
# Collecting information from pages with list of offers
#  1 | 1 page with list: [=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>] 100% | Count of all parsed: 28. Progress ratio: 100 %. Average price: 288 617 716 rub
#
# The collection of information from the pages with list of offers is completed
# Total number of parsed offers: 28.

# %%
import pandas as pd

# %%
columns_names = ['author', 'author_type', 'location', 'deal_type', 'accommodation_type', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district', 'street', 'house_number', 'underground', 'residential_complex']
df = pd.read_csv("C:/Users/user/Videos/Roblox/1Интенсив/cian_parsing.csv", on_bad_lines="skip", names=columns_names)
df
# Out:
#                  author        author_type location deal_type  \
# 0                Sminex          developer   Москва      sale
# 1            ZIP Realty  real_estate_agent   Москва      sale
# 2           ID 18174647            realtor   Москва      sale
# 3                VESPER          developer   Москва      sale
# 4      Monumental Group  real_estate_agent   Москва      sale
# ...                 ...                ...      ...       ...
# 11830     Доступный дом  real_estate_agent   Москва      sale
# 11831  Absolute Premium          developer   Москва      sale
# 11832    Оксана Гимишян            realtor   Москва      sale
# 11833            Пионер          developer   Москва      sale
# 11834   PROНЕДВИЖИМОСТЬ  real_estate_agent   Москва      sale
#
#       accommodation_type  floors_count  rooms_count  total_meters  \
# 0                   flat            12            2          86.1
# 1                   flat            20            3         110.7
# 2                   flat            31            5         246.7
# 3                   flat             9            2         104.2
# 4                   flat             7            4         160.0
# ...                  ...           ...          ...           ...
# 11830               flat            17            1          35.4
# 11831               flat            18            1          49.8
# 11832               flat            12            1          38.7
# 11833               flat            11            1          55.8
# 11834               flat            12            1          33.5
#
#              price             district                  street house_number  \
# 0      213680000.0            Хамовники  Фрунзенская набережная           30
# 1      122000000.0          Пресненский               Костикова          4к1
# 2      287323255.0  Очаково-Матвеевское              Нежинская           1к1
# 3      150958800.0             Тверской    1-я Тверская-Ямская             2
# 4       99999000.0             Тверской               Тверская          27С2
# ...            ...                  ...                     ...          ...
# 11830   14990000.0                  NaN           Эдварда Грига           15
# 11831   60432000.0            Хамовники                     NaN          NaN
# 11832   15000000.0              Раменки            Улофа Пальме            3
# 11833   52675646.0          Даниловский                     NaN          NaN
# 11834    8000000.0      Чертаново Южное     3-й Дорожный проезд          6К1
#
#                   underground   residential_complex
# 0                 Фрунзенская   Клубный город-парк
# 1             Улица 1905 года                 Lucky
# 2                   Давыдково   Кутузовская Ривьера
# 3                  Маяковская      Vesper Tverskaya
# 4                  Маяковская                   NaN
# ...                       ...                   ...
# 11830                Потапово                   NaN
# 11831          Воробьёвы горы  Коллекция Лужники ЖК
# 11832                 Минская                   NaN
# 11833              Павелецкая               Опус ЖК
# 11834  Улица Академика Янгеля                   NaN
#
# [11835 rows x 14 columns]

# %%
df = df.drop(['residential_complex', 'house_number', 'deal_type', 'street', 'author', 'author_type', 'accommodation_type'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11835 entries, 0 to 11834
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   location      11835 non-null  object
#  1   floors_count  11835 non-null  int64
#  2   rooms_count   11835 non-null  int64
#  3   total_meters  11835 non-null  float64
#  4   price         11757 non-null  float64
#  5   district      6076 non-null   object
#  6   underground   11163 non-null  object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 647.4+ KB

# %%
df
# Out:
#                  Sminex          developer  Москва  sale  flat  12  2   86.1  \
# 0            ZIP Realty  real_estate_agent  Москва  sale  flat  20  3  110.7
# 1           ID 18174647            realtor  Москва  sale  flat  31  5  246.7
# 2                VESPER          developer  Москва  sale  flat   9  2  104.2
# 3      Monumental Group  real_estate_agent  Москва  sale  flat   7  4  160.0
# 4               SHOW ME  real_estate_agent  Москва  sale  flat  85  4  294.6
# ...                 ...                ...     ...   ...   ...  .. ..    ...
# 11829     Доступный дом  real_estate_agent  Москва  sale  flat  17  1   35.4
# 11830  Absolute Premium          developer  Москва  sale  flat  18  1   49.8
# 11831    Оксана Гимишян            realtor  Москва  sale  flat  12  1   38.7
# 11832            Пионер          developer  Москва  sale  flat  11  1   55.8
# 11833   PROНЕДВИЖИМОСТЬ  real_estate_agent  Москва  sale  flat  12  1   33.5
#
#        213680000.0            Хамовники  \
# 0      122000000.0          Пресненский
# 1      287323255.0  Очаково-Матвеевское
# 2      150958800.0             Тверской
# 3       99999000.0             Тверской
# 4      412440000.0          Пресненский
# ...            ...                  ...
# 11829   14990000.0                  NaN
# 11830   60432000.0            Хамовники
# 11831   15000000.0              Раменки
# 11832   52675646.0          Даниловский
# 11833    8000000.0      Чертаново Южное
#
#                                   Фрунзенская набережная    30  \
# 0                                              Костикова   4к1
# 1                                             Нежинская    1к1
# 2                                   1-я Тверская-Ямская      2
# 3                                              Тверская   27С2
# 4      Московский международный деловой центр Москва-...   NaN
# ...                                                  ...   ...
# 11829                                      Эдварда Грига    15
# 11830                                                NaN   NaN
# 11831                                       Улофа Пальме     3
# 11832                                                NaN   NaN
# 11833                                3-й Дорожный проезд   6К1
#
#                   Фрунзенская   Клубный город-парк
# 0             Улица 1905 года                 Lucky
# 1                   Давыдково   Кутузовская Ривьера
# 2                  Маяковская      Vesper Tverskaya
# 3                  Маяковская                   NaN
# 4               Деловой центр                   NaN
# ...                       ...                   ...
# 11829                Потапово                   NaN
# 11830          Воробьёвы горы  Коллекция Лужники ЖК
# 11831                 Минская                   NaN
# 11832              Павелецкая               Опус ЖК
# 11833  Улица Академика Янгеля                   NaN
#
# [11834 rows x 14 columns]

# %%
def take_info_from_list(val_list):
    val_str = ', '
    if len(val_list) == 0:
        return 'Нету информации'
    else:
        return val_str.join(val_list)

# %%
df
# Out:
#                  Sminex          developer  Москва  sale  flat  12  2   86.1  \
# 0            ZIP Realty  real_estate_agent  Москва  sale  flat  20  3  110.7
# 1           ID 18174647            realtor  Москва  sale  flat  31  5  246.7
# 2                VESPER          developer  Москва  sale  flat   9  2  104.2
# 3      Monumental Group  real_estate_agent  Москва  sale  flat   7  4  160.0
# 4               SHOW ME  real_estate_agent  Москва  sale  flat  85  4  294.6
# ...                 ...                ...     ...   ...   ...  .. ..    ...
# 11829     Доступный дом  real_estate_agent  Москва  sale  flat  17  1   35.4
# 11830  Absolute Premium          developer  Москва  sale  flat  18  1   49.8
# 11831    Оксана Гимишян            realtor  Москва  sale  flat  12  1   38.7
# 11832            Пионер          developer  Москва  sale  flat  11  1   55.8
# 11833   PROНЕДВИЖИМОСТЬ  real_estate_agent  Москва  sale  flat  12  1   33.5
#
#        213680000.0            Хамовники  \
# 0      122000000.0          Пресненский
# 1      287323255.0  Очаково-Матвеевское
# 2      150958800.0             Тверской
# 3       99999000.0             Тверской
# 4      412440000.0          Пресненский
# ...            ...                  ...
# 11829   14990000.0                  NaN
# 11830   60432000.0            Хамовники
# 11831   15000000.0              Раменки
# 11832   52675646.0          Даниловский
# 11833    8000000.0      Чертаново Южное
#
#                                   Фрунзенская набережная    30  \
# 0                                              Костикова   4к1
# 1                                             Нежинская    1к1
# 2                                   1-я Тверская-Ямская      2
# 3                                              Тверская   27С2
# 4      Московский международный деловой центр Москва-...   NaN
# ...                                                  ...   ...
# 11829                                      Эдварда Грига    15
# 11830                                                NaN   NaN
# 11831                                       Улофа Пальме     3
# 11832                                                NaN   NaN
# 11833                                3-й Дорожный проезд   6К1
#
#                   Фрунзенская   Клубный город-парк
# 0             Улица 1905 года                 Lucky
# 1                   Давыдково   Кутузовская Ривьера
# 2                  Маяковская      Vesper Tverskaya
# 3                  Маяковская                   NaN
# 4               Деловой центр                   NaN
# ...                       ...                   ...
# 11829                Потапово                   NaN
# 11830          Воробьёвы горы  Коллекция Лужники ЖК
# 11831                 Минская                   NaN
# 11832              Павелецкая               Опус ЖК
# 11833  Улица Академика Янгеля                   NaN
#
# [11834 rows x 14 columns]

# %%
# !pip install seaborn
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: seaborn in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from seaborn) (2.1.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (2.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from scikit-learn) (2.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\videos\roblox\1интенсив\.venv\lib\site-packages (from scikit-learn) (3.5.0)

# %%
df
# Out:
#                  Sminex          developer  Москва  sale  flat  12  2   86.1  \
# 0            ZIP Realty  real_estate_agent  Москва  sale  flat  20  3  110.7
# 1           ID 18174647            realtor  Москва  sale  flat  31  5  246.7
# 2                VESPER          developer  Москва  sale  flat   9  2  104.2
# 3      Monumental Group  real_estate_agent  Москва  sale  flat   7  4  160.0
# 4               SHOW ME  real_estate_agent  Москва  sale  flat  85  4  294.6
# ...                 ...                ...     ...   ...   ...  .. ..    ...
# 11829     Доступный дом  real_estate_agent  Москва  sale  flat  17  1   35.4
# 11830  Absolute Premium          developer  Москва  sale  flat  18  1   49.8
# 11831    Оксана Гимишян            realtor  Москва  sale  flat  12  1   38.7
# 11832            Пионер          developer  Москва  sale  flat  11  1   55.8
# 11833   PROНЕДВИЖИМОСТЬ  real_estate_agent  Москва  sale  flat  12  1   33.5
#
#        213680000.0            Хамовники  \
# 0      122000000.0          Пресненский
# 1      287323255.0  Очаково-Матвеевское
# 2      150958800.0             Тверской
# 3       99999000.0             Тверской
# 4      412440000.0          Пресненский
# ...            ...                  ...
# 11829   14990000.0                  NaN
# 11830   60432000.0            Хамовники
# 11831   15000000.0              Раменки
# 11832   52675646.0          Даниловский
# 11833    8000000.0      Чертаново Южное
#
#                                   Фрунзенская набережная    30  \
# 0                                              Костикова   4к1
# 1                                             Нежинская    1к1
# 2                                   1-я Тверская-Ямская      2
# 3                                              Тверская   27С2
# 4      Московский международный деловой центр Москва-...   NaN
# ...                                                  ...   ...
# 11829                                      Эдварда Грига    15
# 11830                                                NaN   NaN
# 11831                                       Улофа Пальме     3
# 11832                                                NaN   NaN
# 11833                                3-й Дорожный проезд   6К1
#
#                   Фрунзенская   Клубный город-парк
# 0             Улица 1905 года                 Lucky
# 1                   Давыдково   Кутузовская Ривьера
# 2                  Маяковская      Vesper Tverskaya
# 3                  Маяковская                   NaN
# 4               Деловой центр                   NaN
# ...                       ...                   ...
# 11829                Потапово                   NaN
# 11830          Воробьёвы горы  Коллекция Лужники ЖК
# 11831                 Минская                   NaN
# 11832              Павелецкая               Опус ЖК
# 11833  Улица Академика Янгеля                   NaN
#
# [11834 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['Sminex', 'developer', 'Москва', 'sale', 'flat', '12', '2', '86.1',
#        '213680000.0', 'Хамовники', 'Фрунзенская набережная', '30',
#        'Фрунзенская', 'Клубный город-парк '],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                  Sminex          developer  Москва  sale  flat  12  2   86.1  \
# 0            ZIP Realty  real_estate_agent  Москва  sale  flat  20  3  110.7
# 1           ID 18174647            realtor  Москва  sale  flat  31  5  246.7
# 2                VESPER          developer  Москва  sale  flat   9  2  104.2
# 3      Monumental Group  real_estate_agent  Москва  sale  flat   7  4  160.0
# 4               SHOW ME  real_estate_agent  Москва  sale  flat  85  4  294.6
# ...                 ...                ...     ...   ...   ...  .. ..    ...
# 11829     Доступный дом  real_estate_agent  Москва  sale  flat  17  1   35.4
# 11830  Absolute Premium          developer  Москва  sale  flat  18  1   49.8
# 11831    Оксана Гимишян            realtor  Москва  sale  flat  12  1   38.7
# 11832            Пионер          developer  Москва  sale  flat  11  1   55.8
# 11833   PROНЕДВИЖИМОСТЬ  real_estate_agent  Москва  sale  flat  12  1   33.5
#
#        213680000.0            Хамовники  \
# 0      122000000.0          Пресненский
# 1      287323255.0  Очаково-Матвеевское
# 2      150958800.0             Тверской
# 3       99999000.0             Тверской
# 4      412440000.0          Пресненский
# ...            ...                  ...
# 11829   14990000.0                  NaN
# 11830   60432000.0            Хамовники
# 11831   15000000.0              Раменки
# 11832   52675646.0          Даниловский
# 11833    8000000.0      Чертаново Южное
#
#                                   Фрунзенская набережная    30  \
# 0                                              Костикова   4к1
# 1                                             Нежинская    1к1
# 2                                   1-я Тверская-Ямская      2
# 3                                              Тверская   27С2
# 4      Московский международный деловой центр Москва-...   NaN
# ...                                                  ...   ...
# 11829                                      Эдварда Грига    15
# 11830                                                NaN   NaN
# 11831                                       Улофа Пальме     3
# 11832                                                NaN   NaN
# 11833                                3-й Дорожный проезд   6К1
#
#                   Фрунзенская   Клубный город-парк
# 0             Улица 1905 года                 Lucky
# 1                   Давыдково   Кутузовская Ривьера
# 2                  Маяковская      Vesper Tverskaya
# 3                  Маяковская                   NaN
# 4               Деловой центр                   NaN
# ...                       ...                   ...
# 11829                Потапово                   NaN
# 11830          Воробьёвы горы  Коллекция Лужники ЖК
# 11831                 Минская                   NaN
# 11832              Павелецкая               Опус ЖК
# 11833  Улица Академика Янгеля                   NaN
#
# [11834 rows x 14 columns]>

# %%
df.describe()
# Out:
#                  12             2          86.1   213680000.0
# count  11834.000000  11834.000000  11834.000000  1.175600e+04
# mean      18.006845      2.318236     79.749673  5.564525e+07
# std       12.353529      1.315758     63.927294  1.344301e+08
# min        1.000000     -1.000000      0.300000  6.000000e+05
# 25%        9.000000      1.000000     38.500000  8.189266e+06
# 50%       17.000000      2.000000     61.000000  1.420000e+07
# 75%       23.000000      3.000000     90.892500  4.431182e+07
# max       97.000000      5.000000    663.000000  2.418390e+09

# %%
df = df.dropna()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
columns_names = ['author', 'author_type', 'location', 'deal_type', 'accommodation_type', 'floors_count', 'rooms_count', 'total_meters', 'price', 'district', 'street', 'house_number', 'underground', 'residential_complex']
df = pd.read_csv("C:/Users/user/Videos/Roblox/1Интенсив/cian_parsing.csv", on_bad_lines="skip", names=columns_names)
df
# Out:
#                  author        author_type location deal_type  \
# 0                Sminex          developer   Москва      sale
# 1            ZIP Realty  real_estate_agent   Москва      sale
# 2           ID 18174647            realtor   Москва      sale
# 3                VESPER          developer   Москва      sale
# 4      Monumental Group  real_estate_agent   Москва      sale
# ...                 ...                ...      ...       ...
# 11830     Доступный дом  real_estate_agent   Москва      sale
# 11831  Absolute Premium          developer   Москва      sale
# 11832    Оксана Гимишян            realtor   Москва      sale
# 11833            Пионер          developer   Москва      sale
# 11834   PROНЕДВИЖИМОСТЬ  real_estate_agent   Москва      sale
#
#       accommodation_type  floors_count  rooms_count  total_meters  \
# 0                   flat            12            2          86.1
# 1                   flat            20            3         110.7
# 2                   flat            31            5         246.7
# 3                   flat             9            2         104.2
# 4                   flat             7            4         160.0
# ...                  ...           ...          ...           ...
# 11830               flat            17            1          35.4
# 11831               flat            18            1          49.8
# 11832               flat            12            1          38.7
# 11833               flat            11            1          55.8
# 11834               flat            12            1          33.5
#
#              price             district                  street house_number  \
# 0      213680000.0            Хамовники  Фрунзенская набережная           30
# 1      122000000.0          Пресненский               Костикова          4к1
# 2      287323255.0  Очаково-Матвеевское              Нежинская           1к1
# 3      150958800.0             Тверской    1-я Тверская-Ямская             2
# 4       99999000.0             Тверской               Тверская          27С2
# ...            ...                  ...                     ...          ...
# 11830   14990000.0                  NaN           Эдварда Грига           15
# 11831   60432000.0            Хамовники                     NaN          NaN
# 11832   15000000.0              Раменки            Улофа Пальме            3
# 11833   52675646.0          Даниловский                     NaN          NaN
# 11834    8000000.0      Чертаново Южное     3-й Дорожный проезд          6К1
#
#                   underground   residential_complex
# 0                 Фрунзенская   Клубный город-парк
# 1             Улица 1905 года                 Lucky
# 2                   Давыдково   Кутузовская Ривьера
# 3                  Маяковская      Vesper Tverskaya
# 4                  Маяковская                   NaN
# ...                       ...                   ...
# 11830                Потапово                   NaN
# 11831          Воробьёвы горы  Коллекция Лужники ЖК
# 11832                 Минская                   NaN
# 11833              Павелецкая               Опус ЖК
# 11834  Улица Академика Янгеля                   NaN
#
# [11835 rows x 14 columns]

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['price'], bins=30, kde=True)
plt.title('Распределение цен')
plt.xlabel('Цена')
plt.ylabel('Частота')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['total_meters'], bins=30, kde=True)
plt.title('Распределение площади')
plt.xlabel('Площадь (м²)')
plt.ylabel('Частота')
plt.show()

# %%
numeric_df = df.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Корреляции между числовыми переменными')
plt.show()

# %%
plt.figure(figsize=(24, 12))
sns.countplot(data=df, x='district', order=df['district'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Количество объектов в разных районах')
plt.xlabel('Район')
plt.ylabel('Количество объектов')
plt.show()
# Out:
# ) missing from font(s) DejaVu Sans.ив\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='total_meters', y='price')
plt.title('Зависимость цены от площади')
plt.xlabel('Площадь (м²)')
plt.ylabel('Цена')
plt.show()

# %%
avg_price_per_district = df.groupby('district')['price'].mean().sort_values()
plt.figure(figsize=(24, 12))
avg_price_per_district.plot(kind='bar')
plt.title('Средняя цена по районам')
plt.xlabel('Район')
plt.ylabel('Средняя цена')
plt.show()
# Out:
# ) missing from font(s) DejaVu Sans.ив\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
